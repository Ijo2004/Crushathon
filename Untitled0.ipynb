# %% [markdown]
# <a href="https://colab.research.google.com/github/Ijo2004/Crushathon/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("this is my first ml lap")
# Out:
# this is my first ml lap

# %%
import numpy as np

# %%
np.array(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2970/2544547496.py in <cell line: 0>()
# ----> 1 np.array(data)
#
# NameError: name 'data' is not defined

# %%
import numpy as np
a=np.array([10,20,30,40])
print(a)
# Out:
# [10 20 30 40]

# %%
import numpy as np
a=np.array([[1,2,3],[4,5,6]])
print(a)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np
a=np.array([[1,2,3],[4,5,6]])
print(a.shape)
# Out:
# (2, 3)

# %%
import numpy as np
a=np.array([[1,2,3],[4,5,6]])
print(a.ndim)
# Out:
# 2

# %%
import numpy as np
a=np.zeros(5)
print(a)
# Out:
# [0. 0. 0. 0. 0.]

# %%
import numpy as np
a=np.ones(5)
print(a)
# Out:
# [1. 1. 1. 1. 1.]

# %%
import numpy as np
a=np.arange(1,10,2)
print(a)
# Out:
# [1 3 5 7 9]

# %%
import numpy as np
a=np.array([1,2,3,4])
print(a+5)
# Out:
# [6 7 8 9]

# %%
import numpy as np
a=np.array([1,2,3,4])
print(a*2)
# Out:
# [2 4 6 8]

# %%
import numpy as np
a=np.array([10,20,30,40])
print(np.sum(a))
# Out:
# 100

# %%
import numpy as np
a=np.array([10,20,30,40])
print(np.mean(a))
# Out:
# 25.0

# %%
import numpy as np
a=np.array([10,20,30,40])
print(np.max(a))
print(np.min(a))
# Out:
# 40
# 10

# %%
import numpy as np
a=np.array([10,20,30,40])
print(np.std(a))
# Out:
# 11.180339887498949

# %%
import numpy as np
a=np.array([10,20,30,40])
print(a[0])
print(a[2])
# Out:
# 10
# 30

# %%
import numpy as np
a=np.array([10,20,30,40])
print(a[1:4])
# Out:
# [20 30 40]

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
days= [1,2,3,4,5]
sales= [100,120,130,140,160]
plt.plot(days,sales)
plt.show()

# %%
plt.title("daily sales")
# Out:
# Text(0.5, 1.0, 'daily sales')

# %%
import matplotlib.pyplot as plt
days= [1,2,3,4,5]
sales= [100,120,130,140,160]
plt.plot(days,sales)
plt.title("daily sales")
plt.xlabel("days")
plt.ylabel("sales")
plt.show()

# %%
import matplotlib.pyplot as plt
subjects=["maths","physics","chemistry"]
marks=[80,92,75]
plt.bar(subjects,marks)
plt.title("marks in subjects")
plt.xlabel("subjects")
# Out:
# Text(0.5, 0, 'subjects')
